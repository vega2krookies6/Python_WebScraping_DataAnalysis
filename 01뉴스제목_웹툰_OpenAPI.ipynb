# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url,headers=req_header)
print(res.status_code, res.ok)
# 응답(response)이 OK 이면
if res.ok:    
    # 응답 (response)에서 text 추출
    html = res.text
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html,'html.parser')
    #print(soup)
# CSS 선택자
# print(soup.select("div.sa_text a[href*='mnews/article']"))
print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")))
a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
print(type(a_tags))
# <a> 태그 리스트 순회하기    
for a_tag in a_tags:    
    title = a_tag.text.strip()  #<a>제목</a>
    link = a_tag['href']
    print(title, link)

# 응답(response)이 Error 이면 status code 출력
# Out:
# https://news.naver.com/section/105
# 200 True
# 88
# <class 'bs4.element.ResultSet'>
# 네이버, B2C 키우고 AI B2B로 외연 확장…내년 'AI 팩토리' 첫 매출(종합)
#
# 최수연 네이버 대표 “AI 팩토리, 구조적 성장 위한 투자…내년 수익화”
#
# 게임 속 '신비의 숲'이 현실로…TFT 최대 팬축제 개막
#
# 과기부, K-문샷 AI 과학자 미션 PD 공모…이민형 대표 사임 두달만
#
# 헬로모바일, e북 함께 보는 '알뜰폰 요금제' 출시…교보문고 제휴
#
# 오픈AI 첫 AI 기기는 ‘도넛형 스피커’…내년 출시 목표
#
# 데브시스터즈, 2분기 영업손실 160억원…적자 지속
#
# 카카오 노사, 임금협약 타결…연봉총액 6.3% 인상
#
# '극한 폭염' 비밀 풀리나…'세계 최고 해상도' 태양 표면 사진 공개
#
# SK하이닉스 보통주 375원 현금배당…"주주환원방안 9월내 확정"
#
# K배터리 밸류체인 '시차'…셀은 웃고 소재는 아직
#
# 빅테크는 ASIC, 범용은 엔비디아…좁아지는 K-NPU 입지
#
# '데이터 예측' LG 엑사원 성능, 구글·알리바바 꺾고 세계 1위
#
# 마케팅비 지출 확대에도 엇갈린 수익성… 게임사 2분기 실적 살펴보니
#
# 구글맵, 음식 주문·호텔 예약 연결까지…'AI 비서'로 진화
#
# 144만대 잭팟 ‘갤Z8’ 시리즈…‘폴더블’ 전쟁은 이제 시작이라는데
#
# AI가 만든 ‘자연에 없는 바이러스’…“생명공학의 확장이자 인류에 위협”
#
# 데브시스터즈, 비용 다이어트에도 2분기 적자…크럼블 3분기 반등 시험대
#
# 공무원이 만든 AI, 전 부처가 함께 쓴다…'AI 정부 실험실' 확산 시동
#
# [유미's 픽] '풀스택' 믿었던 구글, 제미나이 위기 불렀나…인력·조직도 '흔들'
#
# 애플, 日서 아이폰 가격 올리자 중고폰 주문량 2배 껑충… 리퍼폰 패널은 신제품용 추월
#
# 엔비디아도 인정했다…"미래 AI 승부처는 '메모리 지휘' 능력"
#
# “은하 중심에만 있는 줄 알았는데”…우주 외곽서 별 삼키다 적발된 ‘떠돌이 블랙홀’
#
# "바람 없이 목 뒤 시원하게"…소니 웨어러블 온도조절기 써보니
#
# 자연에 없는 바이러스, AI가 만들었다…감염·증식도 가능
#
# 라이엇 "한국의 열정, TFT 향후 7년 밑거름…전용 클라이언트 10월 출격"
#
# 김병수 로보티즈 대표, 887억 지분 매각…자회사 로보티즈AI에 사재 투입
#
# "7년간 18번의 큰 변화"…라이엇게임즈가 밝힌 'TFT' 인기 비결은
#
# AMD, AI 반도체에 ‘지름길’ 뚫는다… 캐나다 스타트업 ‘탈라스’ 인수 의미는
#
# "부모님께 미안"…얹혀사는 취준생들, 독립 미루는 이유
#
# 폭염에 산불까지…워싱턴 덮친 최악의 산불, 우주서 봤더니 [우주서 본 지구]
#
# 국내 대리인 신고 '앤트로픽'뿐…정부, 해외 AI 기업과 연내 회동
#
# K-양극재, LFP 양극재 출하 초읽기…탈중국 ESS 수요 정조준 [배터리레이다]
#
# [22대 AI 입법 후반전④] “AI 속도 모르는데”…AI 기반 채용·평가 규제 실효성은?
#
# [팩플] 윤곽 드러난 오픈AI의 AI 하드웨어는 도넛 모양 스피커
#
# [글로벌 vs 국내 보안맞수] 멘로시큐리티-소프트캠프 RBI 시장서 격돌
#
# 삼성전자, CSS 사업팀 인력 60% 재배치…메모리·파운드리로 이동
#
# 2분기 호실적 낸 기판 업계…AI 훈풍 하반기도 잇는다
#
# "태블릿을 품었다" 여권폰을 펼치니 또 다른 세상이…[잇:써봐]
#
# 인간통제 뚫은 AI…"지능 폭발 전에 멈춰야합니다"
#
# 점유율 1.6% 대만 난야, 15조원 들여 EUV 공장 건설
#
# AI에 현금 쏟아붓는 구글, 또 36조원 빚낸다
#
# AI가 바이러스 ‘전체 설계도’ 만들었다…실제로 감염·증식까지
#
# 단순히 졸음 깨우던 시대 끝…원인 직접 잡는 기면증 신약 나왔다

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

def print_news(sid, section):  #print_new(103,'생활/문화') 
    pass

# %%
print_news(103,section_dict[103])

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':''
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    pass
    # requests 의 get(url, headers) 함수 호출하기 
        
        # binary 응답 데이터 가져오기
        
        # url에서 파일명만 추출하기
        
        # binday data를 file에 write하기

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### .env 파일에서 환경변수 읽어오기
# * CLIENT_ID와 CLIENT_SECRET 환경변수 읽어오기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * [네이버개발자가이드](https://developers.naver.com/docs/utils/captcha/examples/)
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# ### 5-1. 블로그 검색하기
# * 네이버 개발자센터에서 제공하는 검색 API 사용하기

# %%
import requests
from pprint import pprint

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 [{},{},{}]
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %% [markdown]
# ### 5-2. 블로그 검색하기
# * 네이버 API HUB (NAVER Cloud)에서 제공하는 검색 API 사용하기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %%
import requests
from pprint import pprint

headers = {
    'X-NCP-APIGW-API-KEY-ID': CLIENT_ID,
    'X-NCP-APIGW-API-KEY': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}
domain_url = 'https://naverapihub.apigw.ntruss.com'
url = f'{domain_url}/search/v1/blog'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %%
# data/blog.json 파일 생성하기
import json

with open('data/blog.json','w', encoding='utf-8') as file:
    json.dump(items_data, file)
